# %%
from exoexplorations import *
show_transit_video()

# %%
# adjust the planet and the star's radius
# make star less than 0.5 the smallest imsize 
planet_radius, star_radius = 100, 100
inclination = 0

# %%
simulate(planet_radius, star_radius, inclination)
